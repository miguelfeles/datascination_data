# %%
import requests
from bs4 import BeautifulSoup

# Define the search query
query = "Somos una  empresas de Ciencia De Datos"

# URL encode the query
search_url_bing = f"https://www.bing.com/search?q={query.replace(' ', '+')}"
search_url_duckduckgo = f"https://duckduckgo.com/html/?q={query.replace(' ', '+')}"

# Define headers with a user-agent that simulates a browser
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'
}

def scrape_duckduckgo():
    response = requests.get(search_url_duckduckgo, headers=headers)
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')
        # Find all results
        results = soup.find_all('div', {'class': 'result__body'})
        for result in results:
            title = result.find('a', {'class': 'result__a'}).text
            link = result.find('a', {'class': 'result__a'})['href']
            snippet = result.find('a', {'class': 'result__snippet'}).text if result.find('a', {'class': 'result__snippet'}) else 'No snippet available'
            print(f"Title: {title}\nLink: {link}\nSnippet: {snippet}\n")
    else:
        print(f"Failed to retrieve DuckDuckGo results. Status code: {response.status_code}")

# Perform scraping
print("Scraping Bing:")
#scrape_bing()

print("\nScraping DuckDuckGo:")
scrape_duckduckgo()

scrape_duckduckgo()
# Out:
# Scraping Bing:
#
# Scraping DuckDuckGo:
# Title: Ciencia de datos - Nielsen
# Link: https://www.nielsen.com/es/careers/data-science/
# Snippet: Quienes somos. La ciencia de datos es el núcleo de nuestro negocio. Las tecnologías, los activos y los datos únicos de Nielsen hacen que sea un lugar interesante y desafiante para trabajar para los científicos de datos. ... "Nielsen es una empresa de investigación de mercado, por lo que, por supuesto, existen numerosas formas en las que ...
#
# Title: Quiénes somos - JAKALA
# Link: https://www.jakala.com/es/sobre-nosotros-quienes-somos
# Snippet: Somos una empresa de datos, IA y experiencias que logra un impacto útil y duradero a nivel mundial. Trabajando en estrecha colaboración con nuestros clientes, perfilamos trayectorias de crecimiento fundamentadas en los datos y en información reveladora como garantía de que proporcionamos resultados concretos y medibles, mientras nuestros profundos conocimientos de tecnología y ...
#
# ...
